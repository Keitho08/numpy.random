# %% [markdown]
# # The Numpy Random Package
# [Official Documentation](https://numpy.org/doc/stable/reference/random/index.html)
#
# [Useful Python Numpy Link](https://realpython.com/python-random/)
# ***

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [12, 6] # CHANGES DEFAULT PLOT SIZE 
plt.style.use('ggplot') # changes default plot style

# %% [markdown]
# Seeding is important in random number generation.

# %% [markdown]
# <br>
#
# ### numy.random.normal
# https://numpy.org/doc/stable/reference/random/generated/numpy.random.normal.html
# ***

# %%
mu, sigma = 0, 0.1 # mean and standard deviation
s = np.random.normal(mu, sigma, 1000) #stored in s variable

# %%
s # RIGHT CLICK ENABLE SCROLLING FOR OUTPUTS
# Out:
# array([ 3.26016196e-02,  3.89344275e-02,  1.84237989e-01,  9.71684024e-02,
#         5.63084912e-02,  1.80638269e-01,  1.03594184e-01, -4.67641504e-02,
#         1.61473298e-02,  2.04874311e-02, -1.20277534e-01,  1.92623273e-01,
#         4.38142070e-02, -1.42937712e-02,  1.11804100e-02,  5.13551027e-02,
#        -3.58703822e-02,  1.90499969e-01, -3.67353956e-02, -2.72556993e-02,
#         4.76069407e-02,  2.38208092e-01,  3.05162881e-02, -1.75537797e-01,
#         1.44807807e-01,  5.13642910e-02, -4.70187356e-02,  9.71146799e-02,
#        -2.37325766e-01,  1.18433917e-01,  6.37676395e-02,  1.73219809e-01,
#         2.58806640e-01, -7.92959985e-02,  2.23345006e-01, -1.77824621e-01,
#         2.02811854e-01,  4.04520924e-02, -4.36302554e-02, -9.31503591e-03,
#         6.61230572e-02, -2.74947255e-02,  2.23640126e-01, -4.16802171e-02,
#         1.22579020e-01,  2.81127087e-02, -1.29785607e-01,  1.61105105e-02,
# ...

# %%
s[:10] # UP TO BUT NOT INCLUDING ITEM AT INDEX 10
# Out:
# array([ 0.03260162,  0.03893443,  0.18423799,  0.0971684 ,  0.05630849,
#         0.18063827,  0.10359418, -0.04676415,  0.01614733,  0.02048743])

# %%
count, bins, ignored = plt.hist(s, 30, density=True)
plt.plot(bins, 1/(sigma * np.sqrt(2 * np.pi)) * np.exp( - (bins - mu)**2 / (2 * sigma**2) ),
         linewidth=2, color='b')
plt.show() # review cut to 79 spaces, use functions for arguements

# %%
plt.rcParams['figure.figsize'] = [12, 6] # CHANGES DEFAULT PLOT SIZE 
count, bins, ignored = plt.hist(s, 30, density=True)
plt.plot(bins, 1/(sigma * np.sqrt(2 * np.pi)) * np.exp( - (bins - mu)**2 / (2 * sigma**2) ),
         linewidth=2, color='b')
plt.show() # review cut to 79 spaces, use functions for arguements

# %% [markdown]
# ## References
# - https://www.datacamp.com/community/tutorials/numpy-random
# - numpy random normal
# - pyhton style guide https://www.python.org/dev/peps/pep-0008/
# - MATPLOTLIB STYLES

# %% [markdown]
# ## End
